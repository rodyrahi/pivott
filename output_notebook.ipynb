# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_frame = pd.read_csv("F:/pivott/pivott/test_data.csv")

# %%
data_frame = data_frame.drop(columns=['raj'])

# %%
data_frame[['city']].fillna(data_frame[['city']].mean(), inplace=True)

# %%
data_frame = data_frame.drop(index=data_frame[data_frame[['age']] > data_frame[['age']].quantile(0.75) + 1.5 * (data_frame[['age']].quantile(0.75) - data_frame[['age']].quantile(0.25))].index)
